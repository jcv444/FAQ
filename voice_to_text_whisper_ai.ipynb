# %% [markdown]
# <a href="https://colab.research.google.com/github/jcv444/FAQ/blob/master/voice_to_text_whisper_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Whisper

# %%
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg

# %% [markdown]
# # Upload .WAV file and change the directory, then run it 👌

# %%
# Run Whisper AI:
# !whisper /content/untitled.wav --model medium.en

# Additional arguments:
# !whisper -h
